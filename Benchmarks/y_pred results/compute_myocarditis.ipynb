# %% [markdown]
# # Compute Metrics

# %%
import compute_metrics as cm

# %%
data_name = 'Myocarditis'
yaml_name = 'myocarditis'
methods = ['SCDISENTANGLE', 'CPA']
cov_key = 'donor'
cond_key = 'tissue'
control_name = 'Blood'
stim_name = 'Heart'
degs_key = 'rank_genes_groups_tissue'
ood_covs = ['SIC_264', 'SIC_171', 'SIC_258', 'SIC_177', 'SIC_48', 'SIC_232'] #['SIC_264', 'SIC_171', 'SIC_258', 'SIC_153', 'SIC_48', 'SIC_232', 'SIC_177']

# %%
cm.compute_metrics(
    data_name=data_name,
    yaml_name=yaml_name,
    methods=['CPA'],#methods,
    cov_key=cov_key,
    cond_key=cond_key,
    control_name=control_name,
    stim_name=stim_name,
    degs_key=degs_key,
    ood_covs=ood_covs,
    #seed_list=[42]
)
# Out:
#   0%|                                                                                                                                                                                                                   | 0/6 [00:00<?, ?it/s]
# Computing metrics for SIC_264
# adata.X seems to be already log-transformed.
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
cm.compute_metrics_baselines(
    data_name=data_name,
    methods=['Pert Mean', 'Ctrl Mean'],
    cov_key=cov_key,
    cond_key=cond_key,
    control_name=control_name,
    stim_name=stim_name,
    degs_key=degs_key,
    ood_covs=ood_covs,
    #seed_list=[42]
)
# Out:
#   0%|                                                                                                                                                                                                                   | 0/6 [00:00<?, ?it/s]
# Computing metrics for SIC_264
# adata.X seems to be already log-transformed.
# /data/Experiments/Benchmark/SCDISENTANGLE_REPRODUCE/Benchmarks/y_pred results/metrics_tools.py:247: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   pear_mean_delta, _ = pearsonr(true_delta_mean, pred_delta_mean)
# /data/Experiments/Benchmark/SCDISENTANGLE_REPRODUCE/Benchmarks/y_pred results/metrics_tools.py:247: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   pear_mean_delta, _ = pearsonr(true_delta_mean, pred_delta_mean)
# ...

# %% [markdown]
# # Export results

# %%
import os
import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import hygeia.utils.hplots as hp
import metrics_tools as mt

# %%
data_name = 'Myocarditis'
cov_key = 'donor'
cond_key = 'tissue'
stim_name = 'Heart'
control_name = 'Blood'
covs =  ['SIC_264', 'SIC_171', 'SIC_258', 'SIC_177', 'SIC_48', 'SIC_232'] #['SIC_264', 'SIC_171', 'SIC_258', 'SIC_153', 'SIC_48', 'SIC_232', 'SIC_177']

all_results = []
for cov in covs:
    for i in range(1, 11):
        all_results.append(f'{cov}_{i}')

# %%
base_path = f'results/{data_name}'

# %%
colors = {
    'scDisentangle': '#d62728',
    'CPA': '#CC79A7',
    # 'Pert Mean': '#698396',
    # 'Ctrl Mean': '#00FFFF',
    }

# %%
folder_paths = {
     'scDisentangle': f'{base_path}/SCDISENTANGLE/',
     'CPA': f'{base_path}/CPA/',
     # 'Pert Mean': f'{base_path}/Pert Mean',
     # 'Ctrl Mean': f'{base_path}/Ctrl Mean',
}

# %%
n_degs_list = ['200', '100', '50', '20', '10']
metric_name = 'Perturbed Reference Pearson Delta'

metrics = mt.get_results(
    folder_paths, 
    metric_name=metric_name, 
    perts = all_results, 
    n_degs_list=n_degs_list
)

pvals, stars = mt.compute_pvalues(
    metrics,
    metric_name=metric_name,
    higher_is_better=None,
    anchor_method='scDisentangle'
)

records = hp.plot_data(
            metrics,
            plot_type='barplot', 
            save_path=None,
            y_name=metric_name, 
            legend=True, 
            title=metric_name,
            colors=colors,
            show_grid=False,
            sort_order=None,
            stars=stars
        )
# Out:
# Using 60 perturbation
# /home/SE/Desktop/Projects/SCDISENTANGLE/hygeia/hygeia/utils/hplots.py:273: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %%
np.mean(metrics['scDisentangle']['10'])

# %%
np.mean(metrics['Pert Mean']['10'])
