# %%
import os
import torch
import numpy as np 
import random
import scanpy as sc
import anndata as ad
from icecream import ic

from scDisInFact import scdisinfact, create_scdisinfact_dataset
from scDisInFact import utils

# %%
def set_seed(seed):
    ic('Setting seed to', seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
adata_path = '/data/Experiments/Benchmark/SCDISENTANGLE_REPRODUCE/Datasets/preprocessed_datasets/kang.h5ad'
cov_key = "cell_type"
cond_key = "condition"
ood_cov = "B"
control_name = "control"
stim_name = "stimulated"
vars_to_predict = ['stimulated', 'control']
categorical_attributes = ['condition', 'cell_type'] # Should be in this order: cond, cov
seed_nb = 1
device_nb = 1

# %%
device =  torch.device(f"cuda:{device_nb}" if torch.cuda.is_available() else "cpu")

# %%
# Set seed
set_seed(seed_nb)
# Out:
# ic| 'Setting seed to', seed: 1

# %%
# Read adata
adata = sc.read_h5ad(adata_path)

try:
    adata.X = adata.X.toarray()
except:
    print('adata matrix is already in array format')
# Out:
# adata matrix is already in array format

# %%
adata.obs['batch_placeholder'] = [0] * adata.shape[0]

# %%
adata.obs[f'{cond_key}_org'] = adata.obs[cond_key].copy()

# %%
counts = adata.X
meta_cells = adata.obs

# Convert columns to str
for _col in categorical_attributes:
    meta_cells[_col] = meta_cells[_col].astype(str)

# %%
# Train and test ood
test_idx = (meta_cells[f'split_{stim_name}_{ood_cov}'] == 'ood')
train_idx = ~test_idx

# Cells used as sources for counterfactual prediction:
# control condition, specific covariate, and in the train split.
input_indices = (
        (meta_cells[cond_key] == control_name)
        & (meta_cells[cov_key] == ood_cov)
        & (meta_cells[f'split_{stim_name}_{ood_cov}'] == 'train')
    )

# %%
data_dict = create_scdisinfact_dataset(
        counts[train_idx,:], 
        meta_cells.loc[train_idx,:], 
        condition_key = categorical_attributes, 
        batch_key = "batch_placeholder"
    )
# Out:
# Sanity check...
# Finished.
# Create scDisInFact datasets...
# Finished.

# %%
reg_mmd_comm = 1e-4
reg_mmd_diff = 1e-4
reg_kl_comm = 1e-5
reg_kl_diff = 1e-2
reg_class = 1
reg_gl = 1

# %%
Ks = [8] + [2] * len(categorical_attributes)

# %%
batch_size = 64
nepochs = 100
interval = 10
lr = 5e-4

lambs = [reg_mmd_comm, reg_mmd_diff, reg_kl_comm, reg_kl_diff, reg_class, reg_gl]

# %%
model = scdisinfact(
        data_dict = data_dict, 
        Ks = Ks, 
        batch_size = batch_size, 
        interval = interval, 
        lr = lr, 
        reg_mmd_comm = reg_mmd_comm, 
        reg_mmd_diff = reg_mmd_diff, 
        reg_gl = reg_gl, 
        reg_class = reg_class, 
        reg_kl_comm = reg_kl_comm, 
        reg_kl_diff = reg_kl_diff, 
        seed = seed_nb, 
        device = device,
    )

# %%
model.train()
# Out:
# scdisinfact(
#   (Enc_c): Encoder(
#     (fc): FCLayers(
#       (fc_layers): Sequential(
#         (Layer 0): Sequential(
#           (0): Linear(in_features=13404, out_features=128, bias=True)
#           (1): None
#           (2): None
#           (3): ReLU()
#           (4): Dropout(p=0.2, inplace=False)
#         )
#         (Layer 1): Sequential(
#           (0): Linear(in_features=128, out_features=128, bias=True)
#           (1): None
#           (2): None
#           (3): ReLU()
#           (4): Dropout(p=0.2, inplace=False)
#         )
#       )
#     )
#     (mean_layer): Linear(in_features=128, out_features=8, bias=True)
#     (var_layer): Linear(in_features=128, out_features=8, bias=True)
#   )
#   (Enc_ds): ModuleList(
#     (0-1): 2 x Encoder(
#       (fc): FCLayers(
#         (fc_layers): Sequential(
#           (Layer 0): Sequential(
#             (0): Linear(in_features=13404, out_features=128, bias=True)
#             (1): None
#             (2): None
#             (3): ReLU()
#             (4): Dropout(p=0.2, inplace=False)
#           )
#         )
#       )
#       (mean_layer): Linear(in_features=128, out_features=2, bias=True)
#       (var_layer): Linear(in_features=128, out_features=2, bias=True)
#     )
#   )
#   (classifiers): ModuleList(
#     (0): Linear(in_features=2, out_features=2, bias=True)
#     (1): Linear(in_features=2, out_features=8, bias=True)
#   )
#   (diff_prior_means): ParameterList(
#       (0): Parameter containing: [torch.float32 of size 2x2 (cuda:1)]
#       (1): Parameter containing: [torch.float32 of size 8x2 (cuda:1)]
#   )
#   (diff_prior_logvars): ParameterList(
#       (0): Parameter containing: [torch.float32 of size 2x2 (cuda:1)]
#       (1): Parameter containing: [torch.float32 of size 8x2 (cuda:1)]
#   )
#   (Dec): Decoder(
#     (fc): FCLayers(
#       (fc_layers): Sequential(
#         (Layer 0): Sequential(
#           (0): Linear(in_features=12, out_features=128, bias=True)
#           (1): None
#           (2): None
#           (3): ReLU()
#           (4): Dropout(p=0.2, inplace=False)
#         )
#         (Layer 1): Sequential(
#           (0): Linear(in_features=128, out_features=128, bias=True)
#           (1): None
#           (2): None
#           (3): ReLU()
#           (4): Dropout(p=0.2, inplace=False)
#         )
#       )
#     )
#     (output): OutputLayer(
#       (mean_layer): Sequential(
#         (0): Linear(in_features=128, out_features=13404, bias=True)
#         (1): Softplus(beta=1.0, threshold=20.0)
#       )
#       (pi_layer): Sequential(
#         (0): Linear(in_features=128, out_features=13404, bias=True)
#         (1): Sigmoid()
#       )
#       (theta_layer): Sequential(
#         (0): Linear(in_features=128, out_features=13404, bias=True)
#         (1): Softplus(beta=1.0, threshold=20.0)
#       )
#     )
#   )
# )

# %%
losses = model.train_model(nepochs = nepochs, recon_loss = "NB")
# Out:
# Epoch 0, Validating Loss: 4.2188
# 	 loss reconstruction: 1.94981
# 	 loss kl comm: 0.18824
# 	 loss kl diff: 3.77042
# 	 loss mmd common: 4.33069
# 	 loss mmd diff: 19.09957
# 	 loss classification: 2.09541
# 	 loss group lasso diff: 0.13350
# GPU memory usage: 0.000000MB
# Epoch 10, Validating Loss: 1.4110
# 	 loss reconstruction: 0.23145
# 	 loss kl comm: 21.33522
# 	 loss kl diff: 21.91511
# 	 loss mmd common: 13.99707
# 	 loss mmd diff: 4.32577
# 	 loss classification: 0.80714
# 	 loss group lasso diff: 0.15120
# GPU memory usage: 0.000000MB
# Epoch 20, Validating Loss: 1.2558
# 	 loss reconstruction: 0.21589
# 	 loss kl comm: 20.25145
# 	 loss kl diff: 22.37972
# 	 loss mmd common: 13.79798
# 	 loss mmd diff: 3.90825
# 	 loss classification: 0.66420
# 	 loss group lasso diff: 0.14994
# GPU memory usage: 0.000000MB
# Epoch 30, Validating Loss: 1.1807
# 	 loss reconstruction: 0.20893
# 	 loss kl comm: 19.94520
# 	 loss kl diff: 22.70644
# 	 loss mmd common: 11.80556
# 	 loss mmd diff: 3.78259
# 	 loss classification: 0.59683
# 	 loss group lasso diff: 0.14611
# GPU memory usage: 0.000000MB
# Epoch 40, Validating Loss: 1.1205
# 	 loss reconstruction: 0.20435
# 	 loss kl comm: 19.78255
# 	 loss kl diff: 22.59146
# 	 loss mmd common: 10.65529
# 	 loss mmd diff: 3.31422
# 	 loss classification: 0.54635
# 	 loss group lasso diff: 0.14234
# GPU memory usage: 0.000000MB
# Epoch 50, Validating Loss: 1.0752
# 	 loss reconstruction: 0.20174
# 	 loss kl comm: 19.58691
# 	 loss kl diff: 22.50623
# 	 loss mmd common: 10.70404
# 	 loss mmd diff: 3.13997
# 	 loss classification: 0.50776
# 	 loss group lasso diff: 0.13905
# GPU memory usage: 0.000000MB
# Epoch 60, Validating Loss: 1.0355
# 	 loss reconstruction: 0.19983
# 	 loss kl comm: 20.55725
# 	 loss kl diff: 21.92932
# 	 loss mmd common: 11.64795
# 	 loss mmd diff: 2.78629
# 	 loss classification: 0.47855
# 	 loss group lasso diff: 0.13614
# GPU memory usage: 0.000000MB
# Epoch 70, Validating Loss: 1.0038
# 	 loss reconstruction: 0.19806
# 	 loss kl comm: 22.23538
# 	 loss kl diff: 21.59528
# 	 loss mmd common: 13.77935
# 	 loss mmd diff: 3.09790
# 	 loss classification: 0.45409
# 	 loss group lasso diff: 0.13377
# GPU memory usage: 0.000000MB
# Epoch 80, Validating Loss: 0.9709
# 	 loss reconstruction: 0.19569
# 	 loss kl comm: 23.00555
# 	 loss kl diff: 21.24595
# 	 loss mmd common: 13.74609
# 	 loss mmd diff: 4.33224
# 	 loss classification: 0.42900
# 	 loss group lasso diff: 0.13170
# GPU memory usage: 0.000000MB
# Epoch 90, Validating Loss: 0.9441
# 	 loss reconstruction: 0.19454
# 	 loss kl comm: 25.12057
# 	 loss kl diff: 21.13876
# 	 loss mmd common: 12.66922
# 	 loss mmd diff: 2.83316
# 	 loss classification: 0.40629
# 	 loss group lasso diff: 0.13012
# GPU memory usage: 0.000000MB
# Epoch 100, Validating Loss: 0.9179
# 	 loss reconstruction: 0.19336
# 	 loss kl comm: 27.45162
# 	 loss kl diff: 20.99391
# 	 loss mmd common: 12.64009
# 	 loss mmd diff: 2.90906
# 	 loss classification: 0.38375
# 	 loss group lasso diff: 0.12902
# GPU memory usage: 0.000000MB

# %%
_ = model.eval()

# %%
meta_input = meta_cells.loc[input_indices, :]
counts_input = counts[input_indices, :]

# %%
predict_conds = ['stimulated', 'B']

# %%
counts_predict = model.predict_counts(
                input_counts = counts_input,
                meta_cells = meta_input,
                condition_keys = categorical_attributes, 
                batch_key = "batch_placeholder",
                predict_conds = predict_conds, 
                predict_batch = None
            )

adata_pred = sc.AnnData(X = counts_predict, obs=meta_input)

# %%
adata_pred.X.max()
# Out:
# np.float32(317.3731)

# %%
counts_predict = model.predict_counts(
                input_counts = counts_input,
                meta_cells = meta_input,
                condition_keys = categorical_attributes, 
                batch_key = "batch_placeholder",
                predict_conds = None, 
                predict_batch = None
            )

adata_pred_ctrl = sc.AnnData(X = counts_predict, obs=meta_input)

# %%
adata_pred_ctrl.X.max()
# Out:
# np.float32(366.90988)

# %%
import scDisInFact
scDisInFact.__version__
# Out:
# '0.1.0'
