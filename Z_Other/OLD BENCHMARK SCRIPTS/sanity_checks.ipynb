# %%
import scanpy as sc
import numpy as np

# %% [markdown]
# # SCDISENTANGLE

# %%
# Kang:

new_preds = sc.read_h5ad(
    'SCDISENTANGLE/Kang/predictions/kang/B_1.h5ad'
)
old_preds = sc.read_h5ad(
    '/data/Experiments/Benchmark/scdisentangle/Figures/Kang/SCDISENTANGLE/kang/pred_adata/B_1.h5ad'
)
# Out:
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
new_preds_stim = new_preds[new_preds.obs['condition_pred'] == 'stimulated']
new_preds_ctrl = new_preds[new_preds.obs['condition_pred'] == 'control']

mask =  (old_preds.obs['condition_org'] == 'control') & \
(old_preds.obs['cell_type'] == 'B') & (old_preds.obs['split_condition_B'] == 'train')

old_preds = old_preds[mask]
old_preds_stim = old_preds[old_preds.obs['condition_pred'] == 'stimulated']
old_preds_ctrl = old_preds[old_preds.obs['condition_pred'] == 'control']

# %%
old_preds_stim.X.max(), new_preds_stim.X.max()
# Out:
# (array(883.7775, dtype=float32), array(883.7784, dtype=float32))

# %%
old_preds_ctrl.X.max(), new_preds_ctrl.X.max()
# Out:
# (array(409.0589, dtype=float32), array(409.05975, dtype=float32))

# %%
# Minor differences!

# %%
# Liver

# %%
# Kang:

new_preds = sc.read_h5ad(
    'SCDISENTANGLE/Liver/predictions/liver/Periportal_1.h5ad'
)
old_preds = sc.read_h5ad(
    '/data/Experiments/Benchmark/scdisentangle/Figures/Liver/SCDISENTANGLE/liver/pred_adata/Periportal_1.h5ad'
)
# Out:
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
new_preds_stim = new_preds[new_preds.obs['status_control_pred'] == 'Infected']
new_preds_ctrl = new_preds[new_preds.obs['status_control_pred'] == 'Control']

mask =  (old_preds.obs['status_control_org'] == 'Control') & \
(old_preds.obs['zone'] == 'Periportal') & (old_preds.obs['split_status_control_Periportal'] == 'train')

old_preds = old_preds[mask]
old_preds_stim = old_preds[old_preds.obs['status_control_pred'] == 'Infected']
old_preds_ctrl = old_preds[old_preds.obs['status_control_pred'] == 'Control']

# %%
old_preds_stim.X.max(), new_preds_stim.X.max()
# Out:
# (array(4314.408, dtype=float32), array(4314.4097, dtype=float32))

# %%
old_preds_ctrl.X.max(), new_preds_ctrl.X.max()
# Out:
# (array(5091.04, dtype=float32), array(5091.045, dtype=float32))

# %% [markdown]
# # CPA

# %%
# Kang:

new_preds = sc.read_h5ad(
    '../../Benchmarks/CPA/Kang/predictions/CD8 T_4.h5ad'
)
old_preds = sc.read_h5ad(
    '/data/Experiments/Benchmark/scdisentangle/Benchmarks/CPA/Datasets/Kang/condition/pred_adata/CD8 T_4.h5ad'
)
# Out:
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
new_preds_stim = new_preds[new_preds.obs['condition_pred'] == 'stimulated']
new_preds_ctrl = new_preds[new_preds.obs['condition_pred'] == 'control']

mask =  (old_preds.obs['condition_org'] == 'control') & \
(old_preds.obs['cell_type'] == 'CD8 T') & (old_preds.obs['split_stimulated_CD8 T'] == 'train')

old_preds = old_preds[mask]
old_preds_stim = old_preds[old_preds.obs['condition_pred'] == 'stimulated']
old_preds_ctrl = old_preds[old_preds.obs['condition_pred'] == 'control']

# %%
old_preds_stim.X.max(), new_preds_stim.X.max()
# Out:
# (array(344.55298, dtype=float32), array(344.55295, dtype=float32))

# %%
old_preds_ctrl.X.max(), new_preds_ctrl.X.max()
# Out:
# (array(314.3825, dtype=float32), array(314.38272, dtype=float32))

# %%
old_preds_ctrl.X
# Out:
# ArrayView([[4.4692664e-05, 3.8621390e-01, 5.5575747e-05, ...,
#             1.7203308e-06, 3.5475398e-06, 2.3140432e-05],
#            [7.2882476e-04, 1.0164289e-01, 3.0854970e-04, ...,
#             6.3826212e-07, 6.7693168e-06, 4.6986221e-05],
#            [5.2832376e-04, 6.8142337e-01, 8.2875811e-04, ...,
#             1.2347022e-05, 2.8057805e-06, 1.9273714e-06],
#            ...,
#            [1.0990960e-03, 5.3256229e-02, 3.4583602e-04, ...,
#             7.7930808e-06, 1.3180367e-08, 2.0226538e-05],
#            [4.0436219e-03, 2.8445715e-01, 1.8649549e-03, ...,
#             9.4720781e-07, 1.5379094e-07, 9.0581379e-06],
#            [5.6242867e-04, 3.7759375e-02, 6.7945186e-04, ...,
#             6.5788345e-07, 4.9502501e-06, 7.6728730e-07]], dtype=float32)

# %%
new_preds_ctrl.X
# Out:
# ArrayView([[4.4692697e-05, 3.8621399e-01, 5.5575783e-05, ...,
#             1.7203339e-06, 3.5475389e-06, 2.3140450e-05],
#            [7.2882470e-04, 1.0164283e-01, 3.0854964e-04, ...,
#             6.3826201e-07, 6.7693022e-06, 4.6986210e-05],
#            [5.2832376e-04, 6.8142378e-01, 8.2875980e-04, ...,
#             1.2347058e-05, 2.8057937e-06, 1.9273771e-06],
#            ...,
#            [1.0990987e-03, 5.3256273e-02, 3.4583584e-04, ...,
#             7.7931072e-06, 1.3180362e-08, 2.0226549e-05],
#            [4.0436168e-03, 2.8445747e-01, 1.8649529e-03, ...,
#             9.4720940e-07, 1.5379058e-07, 9.0581007e-06],
#            [5.6242943e-04, 3.7759438e-02, 6.7945145e-04, ...,
#             6.5788436e-07, 4.9502569e-06, 7.6728537e-07]], dtype=float32)

# %%
new_preds
# Out:
# AnnData object with n_obs × n_vars = 1084 × 13404
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'stim', 'seurat_annotations', 'integrated_snn_res.0.5', 'seurat_clusters', 'condition', 'cell_type', 'n_counts', 'cov_cond', 'split_stimulated_B', 'split_stimulated_CD14 Mono', 'split_stimulated_CD16 Mono', 'split_stimulated_CD4 T', 'split_stimulated_CD8 T', 'split_stimulated_DC', 'split_stimulated_NK', 'split_stimulated_T', 'sc_cell_ids', 'dose', 'CPA_cat', 'CPA_control', '_scvi_condition', '_scvi_cell_type', '_scvi_CPA_cat', 'condition_org', 'condition_pred'
#     uns: 'X_normalization', 'adata_subset_shape', 'median', 'ood_mean', 'ood_size', 'pred_ood', 'train_mean', 'train_size', 'val_mean', 'val_size'

# %%
new_preds.uns['ood_mean']
# Out:
# 0.11824973

# %%
old_preds.uns['ood_mean']
# Out:
# 0.11824973

# %%
# CPA Failed! stim = ctrl!!!

# %% [markdown]
# # SCDISINFACT

# %%
# Kang:

new_preds = sc.read_h5ad(
    'SCDISINFACT/Kang/predictions/B_1.h5ad'
)
old_preds = sc.read_h5ad(
    '/data/Experiments/Benchmark/scdisentangle/Benchmarks/SCDISINFACT/Datasets/Kang/condition/pred_adata/B_1.h5ad'
)
# Out:
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
new_preds_stim = new_preds[new_preds.obs['condition_pred'] == 'stimulated']
new_preds_ctrl = new_preds[new_preds.obs['condition_pred'] == 'control']

mask =  (old_preds.obs['condition_org'] == 'control') & \
(old_preds.obs['cell_type'] == 'B') & (old_preds.obs['split_stimulated_B'] == 'train')

old_preds = old_preds[mask]
old_preds_stim = old_preds[old_preds.obs['condition_pred'] == 'stimulated']
old_preds_ctrl = old_preds[old_preds.obs['condition_pred'] == 'control']

# %%
old_preds_stim.X.max(), new_preds_stim.X.max()
# Out:
# (array(320.21844, dtype=float32), array(317.3731, dtype=float32))

# %%
old_preds_ctrl.X.max(), new_preds_ctrl.X.max()
# Out:
# (array(367.0455, dtype=float32), array(366.90988, dtype=float32))

# %%
# Failed

# %% [markdown]
# # SCGEN

# %%
# Kang:

new_preds = sc.read_h5ad(
    'SCGEN/Kang/predictions/B_1.h5ad'
)
old_preds = sc.read_h5ad(
    '/data/Experiments/Benchmark/scdisentangle/Benchmarks/SCGEN/Datasets/Kang/condition/pred_adata/B_1.h5ad'
)
# Out:
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
new_preds_stim = new_preds[new_preds.obs['condition_pred'] == 'stimulated']
new_preds_ctrl = new_preds[new_preds.obs['condition_pred'] == 'control']

mask =  (old_preds.obs['condition_org'] == 'control') & \
(old_preds.obs['cell_type'] == 'B') & (old_preds.obs['split_stimulated_B'] == 'train')

old_preds = old_preds[mask]
old_preds_stim = old_preds[old_preds.obs['condition_pred'] == 'stimulated']
old_preds_ctrl = old_preds[old_preds.obs['condition_pred'] == 'control']

# %%
old_preds_stim.X.max(), new_preds_stim.X.max()
# Out:
# (array(4.8498425, dtype=float32), array(4.760956, dtype=float32))

# %%
old_preds_ctrl.X.max(), new_preds_ctrl.X.max()
# Out:
# (array(4.849095, dtype=float32), array(5.026708, dtype=float32))

# %% [markdown]
# # BIOLORD

# %%
# Kang:

new_preds = sc.read_h5ad(
    'BIOLORD/Kang/predictions/B_1.h5ad'
)
old_preds = sc.read_h5ad(
    '/data/Experiments/Benchmark/scdisentangle/Benchmarks/BIOLORD/Datasets/Kang/condition/pred_adata/B_1.h5ad'
)

# %%
new_preds_stim = new_preds[new_preds.obs['condition_pred'] == 'stimulated']
new_preds_ctrl = new_preds[new_preds.obs['condition_pred'] == 'control']

mask =  (old_preds.obs['condition_org'] == 'control') & \
(old_preds.obs['cell_type'] == 'B') & (old_preds.obs['split_stimulated_B'] == 'train')

old_preds = old_preds[mask]
old_preds_stim = old_preds[old_preds.obs['condition_pred'] == 'stimulated']
old_preds_ctrl = old_preds[old_preds.obs['condition_pred'] == 'control']

# %%
old_preds_stim.X.max(), new_preds_stim.X.max()
# Out:
# (array(5.5038514, dtype=float32), array(5.377733, dtype=float32))

# %%
old_preds_ctrl.X.max(), new_preds_ctrl.X.max()
# Out:
# (array(5.115564, dtype=float32), array(5.36272, dtype=float32))

# %%
# FAILED

# %%
import scanpy as sc

# %%
adata_org = sc.read_h5ad('/data/Experiments/Benchmark/scdisentangle/Datasets/preprocessed_datasets/kang.h5ad')

# %%
adata_org
# Out:
# AnnData object with n_obs × n_vars = 13576 × 13404
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'stim', 'seurat_annotations', 'integrated_snn_res.0.5', 'seurat_clusters', 'condition', 'cell_type', 'n_counts', 'cov_cond', 'split_stimulated_B', 'split_stimulated_CD14 Mono', 'split_stimulated_CD16 Mono', 'split_stimulated_CD4 T', 'split_stimulated_CD8 T', 'split_stimulated_DC', 'split_stimulated_NK', 'split_stimulated_T', 'sc_cell_ids'
#     var: 'n_counts'
#     uns: 'log1p', 'rank_genes_groups_condition'
#     layers: 'counts'

# %%
adata_new = sc.read_h5ad('/data/Experiments/Benchmark/SCDISENTANGLE_REPRODUCE/Datasets/preprocessed_datasets/kang.h5ad')
