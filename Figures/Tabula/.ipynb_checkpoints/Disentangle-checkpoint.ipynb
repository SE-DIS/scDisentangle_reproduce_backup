# %% [markdown]
# # Imports

# %%
import os
import torch
import scanpy as sc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from sklearn.feature_selection import mutual_info_regression
from scdisentangle.train.tools import get_trainer, set_seed
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Set seed

# %%
seed_nb = 42
set_seed(seed_nb)
# Out:
# ic| 'Setting seed to', seed: 42

# %% [markdown]
# # Get Trainer

# %%
yaml_path = '../../Benchmarks/SCDISENTANGLE/Tabula/configs/tabula.yaml'

# %%
trainer = get_trainer(yaml_path, wandb_log=False, seed_nb=seed_nb)
# Out:
# ic| 'Setting seed to', seed: 42
# ic| 'Creating cell mappings'
# ic| 'Creating inputs'
# ic| 'Creating inputs'
# Wandb is off

# %% [markdown]
# # Train

# %%
#trainer.train()

# %% [markdown]
# # Load best weights

# %%
weights_path = '../../Benchmarks/SCDISENTANGLE/Tabula/weights/tabula/5/pulmonary alveolar type 2 cell/r2_mean_criterion_10_all'
trainer.load_weights(weights_path)
# Out:
# Loading weights from ../../Benchmarks/SCDISENTANGLE/Tabula/weights/tabula/5/pulmonary alveolar type 2 cell/r2_mean_criterion_10_all

# %% [markdown]
# # Get Latent

# %%
counterfactual_dict = {'specie': 'sapiens'}

# %% [markdown]
# # Inference

# %%
adata = trainer.predict(
    trainer.dataset.data.copy(), 
    counterfactual_dict=counterfactual_dict, 
    bs=256,
    get_reconstruction=True
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 adata = trainer.predict(
#       2     trainer.dataset.data.copy(),
#       3     counterfactual_dict=counterfactual_dict,
#       4     bs=256,
#       5     get_reconstruction=True
#       6 )
#
# TypeError: CustomIterations.predict() got an unexpected keyword argument 'get_reconstruction'

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
# Out:
# adata.X seems to be already log-transformed.

# %%
sc.pp.neighbors(adata)

# %%
sc.pp.pca(adata)

# %%
sc.pl.pca(adata_dis, color='specie_org')

# %%
sc.pl.umap(adata_dis, color='cell_type')
