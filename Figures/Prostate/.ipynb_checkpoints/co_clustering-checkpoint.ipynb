# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import os

import local_tools as lt

# %% [markdown]
# # Original data

# %%
save_path = '/data/scDisentangle figures/Prostate/co_clustering'
os.makedirs(save_path, exist_ok=True)

# %%
adata_template = sc.read_h5ad(
    '/data/Experiments/Benchmark/SCDISENTANGLE_REPRODUCE/Datasets/preprocessed_datasets/prostate.h5ad'
)

# %% [markdown]
# # Renaming and colors

# %%
mapping = {
        'T00': 'T0',
        'T01_Cast_Day1': 'C1',
        'T02_Cast_Day7': 'C7',
        'T03_Cast_Day14': 'C14',
        'T04_Cast_Day28': 'C28',
        'T05_Regen_Day1': 'R1',
        'T06_Regen_Day2': 'R2',
        'T07_Regen_Day3': 'R3',
        'T08_Regen_Day7': 'R7',
        'T09_Regen_Day14': 'R14',
        'T10_Regen_Day28': 'R28'
    }

palette = {
    'T0': '#1f77b4',
    'C1': '#ff7f0e',
    'C7': '#279e68',
    'C14': '#d62728',
    'C28': '#aa40fc',
    'R1': '#8c564b',
    'R2': '#e377c2',
    'R3': '#b5bd61',
    'R7': '#17becf',
    'R14': '#aec7e8',
    'R28': '#ffbb78'
    }

time_points = list(mapping.keys())
time_points
# Out:
# ['T00',
#  'T01_Cast_Day1',
#  'T02_Cast_Day7',
#  'T03_Cast_Day14',
#  'T04_Cast_Day28',
#  'T05_Regen_Day1',
#  'T06_Regen_Day2',
#  'T07_Regen_Day3',
#  'T08_Regen_Day7',
#  'T09_Regen_Day14',
#  'T10_Regen_Day28']

# %% [markdown]
# # Compute MAE between L1 & L2

# %%
def compute_maes(time_points, n_pcs=2):

    outs = {'gt': {}, 'pred': {}, 'psca_pred':[], 'adata_pred':[], 'adata_gt':[]}

    for tp in tqdm(time_points):
        pred = sc.read_h5ad(f'predictions/{tp}.h5ad')
        gt = sc.read_h5ad(f'ground_truth/{tp}.h5ad')

        pred.var_names = adata_template.var_names.copy()
        gt.var_names = adata_template.var_names.copy()

        pred_stim = pred[pred.obs['time_pred'] == tp].copy()
        gt_stim = gt[gt.obs['time'] == tp].copy()

        outs['psca_pred'].append(
            pred_stim[pred_stim.obs['predType'] == 'Epi_Luminal_2Psca'][:, 'Psca'].X.squeeze()
        )

        outs['adata_pred'].append(pred_stim[pred_stim.obs['predType'] == 'Epi_Luminal_2Psca'])
        outs['adata_gt'].append(gt_stim[gt_stim.obs['predType'] == 'Epi_Luminal_2Psca'])

        X_gt = gt_stim.X 
        X_pred = pred_stim.X
      
        pca = PCA(n_components=n_pcs)
        Z_gt = pca.fit_transform(X_gt)
        Z_pred = pca.transform(X_pred)

        gt_l1 = gt_stim.obs['predType'] == 'Epi_Luminal_1'
        gt_l2 = gt_stim.obs['predType'] == 'Epi_Luminal_2Psca'

        pred_l1 = pred_stim.obs['predType'] == 'Epi_Luminal_1'
        pred_l2 = pred_stim.obs['predType'] == 'Epi_Luminal_2Psca'

        gt_c_l1 = Z_gt[gt_l1].mean(axis=0)
        gt_c_l2 = Z_gt[gt_l2].mean(axis=0)

        pred_c_l1 = Z_pred[pred_l1].mean(axis=0)
        pred_c_l2 = Z_pred[pred_l2].mean(axis=0)

        mae_gt = np.abs(gt_c_l1 - gt_c_l2).mean()

        mae_pred = np.abs(pred_c_l1 - pred_c_l2).mean()
        
        outs['gt'][mapping[tp]] = mae_gt
        outs['pred'][mapping[tp]] = mae_pred

    return outs

# %%
outs = compute_maes(time_points, n_pcs=2)
# Out:
#   9%|██████████████████▎                                                                                                                                                                                       | 1/11 [00:00<00:08,  1.12it/s]/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#  18%|████████████████████████████████████▋                                                                                                                                                                     | 2/11 [00:01<00:07,  1.16it/s]/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#  27%|███████████████████████████████████████████████████████                                                                                                                                                   | 3/11 [00:03<00:08,  1.10s/it]/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#  36%|█████████████████████████████████████████████████████████████████████████▍                                                                                                                                | 4/11 [00:04<00:07,  1.05s/it]/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#  45%|███████████████████████████████████████████████████████████████████████████████████████████▊                                                                                                              | 5/11 [00:04<00:05,  1.00it/s]/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#  55%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                           | 6/11 [00:05<00:04,  1.01it/s]/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#  64%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                         | 7/11 [00:06<00:03,  1.05it/s]/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#  73%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                       | 8/11 [00:07<00:02,  1.04it/s]/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#  82%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                    | 9/11 [00:08<00:01,  1.05it/s]/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#  91%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                  | 10/11 [00:09<00:00,  1.02it/s]/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:10<00:00,  1.03it/s]

# %% [markdown]
# # Psca Expression over C/R cycle

# %%
adata_cat_pred = ad.concat(outs['adata_pred'])
adata_cat_pred = lt.rename_time_points(
    adata_cat_pred, 
    obs_name='time_pred',
    obs_name_renamed='time'
    )

adata_cat_gt = ad.concat(outs['adata_gt'])
adata_cat_gt = lt.rename_time_points(
    adata_cat_gt, 
    obs_name='time',
    obs_name_renamed='time'
)
# Out:
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata_cat_pred.obs['predType']
# Out:
# T00_Epi_2_id-GCTCCTAAGCGGATCA         Epi_Luminal_2Psca
# T00_Epi_2_id-GCTGCTTCAGTATCTG         Epi_Luminal_2Psca
# T00_Unsorted_1_id-AGCTCTCCAACTGGCC    Epi_Luminal_2Psca
# T00_Unsorted_1_id-CAACTAGTCTGAGTGT    Epi_Luminal_2Psca
# T00_Unsorted_1_id-CAGCCGATCAACACCA    Epi_Luminal_2Psca
#                                             ...
# T00_intact_2_id-GTCACGGAGACCCACC      Epi_Luminal_2Psca
# T00_intact_2_id-TAGACCATCGTACCGG      Epi_Luminal_2Psca
# T00_intact_2_id-TGCCCTAAGATATGCA      Epi_Luminal_2Psca
# T00_intact_2_id-TGGGAAGAGGTTACCT      Epi_Luminal_2Psca
# T00_intact_2_id-TTTATGCGTGATGATA      Epi_Luminal_2Psca
# Name: predType, Length: 1067, dtype: category
# Categories (1, object): ['Epi_Luminal_2Psca']

# %%
# Violon plot

# %%
for gene_name in ['Psca', 'Pbsn', 'Tgm4', 'Krt18']:
    sc.pl.violin(
        adata_cat_pred[~adata_cat_pred.obs['time'].isin(['T0', 'C1'])],
        keys=gene_name,
        groupby="time",
        stripplot=True,
        jitter=True,
        multi_panel=False,
        show=False,
        palette=palette
    )

    plt.savefig(f'{save_path}/violin_pred_{gene_name}.png', dpi=600)
    plt.savefig(f'{save_path}/violin_pred_{gene_name}.pdf', dpi=600)

    sc.pl.violin(
        adata_cat_gt[~adata_cat_gt.obs['time'].isin(['T0', 'C1'])],
        keys=gene_name,
        groupby="time",
        stripplot=True,
        jitter=True,
        multi_panel=False,
        show=False,
        palette=palette
    )

    plt.savefig(f'{save_path}/violin_gt_{gene_name}.png', dpi=600)
    plt.savefig(f'{save_path}/violin_gt_{gene_name}.pdf', dpi=600)
# Out:
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:967: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:967: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:967: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:967: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:967: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:967: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:967: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/scanpy/plotting/_anndata.py:967: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
# Boxplot

# %%
new_palette = {k:v for k,v in palette.items() if not k == 'C1'}

# %%
lt.plot_gene_expression_box(
    list(new_palette.keys()), 
    [outs['psca_pred'][0]] + outs['psca_pred'][2:], 
    gene_name="", 
    save_path=f'{save_path}/boxplots',
    color_mapping=new_palette, 
    y_max=5.5
)
# Out:
# <module 'matplotlib.pyplot' from '/home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # Line plots of MAEs between L1 and L2 cell over C/R cycle

# %%
# Both Observed and Predicted combined in a single plot

# %%
color_pred = '#d62728'
color_gt = '#117733'

_time_points = list(palette.keys())[2:]#['T0', 'C7', 'C14', 'C28', 'R7', 'R14', 'R28']


gt_vals = [outs['gt'][t] for t in _time_points]
pred_vals = [outs['pred'][t] for t in _time_points]

df_pred = pd.DataFrame({
    'time': _time_points,
    'value': pred_vals,
    
})

df_gt = pd.DataFrame({
    'time': _time_points,
    'value': gt_vals,
})

plt.figure(figsize=(8, 4))
sns.lineplot(
    data=df_pred,
    x='time',
    y='value',
    marker='o',
    linestyle='-',
    linewidth=2.5,
    markersize=8,
    markeredgecolor='k',
    color=color_pred,
    label='Predicted',
)

sns.lineplot(
    data=df_gt,
    x='time',
    y='value',
    marker='o',
    linestyle='-',
    linewidth=2.5,
    markersize=8,
    markeredgecolor='k',
    color=color_gt,
    label='Observed',
)

plt.xticks(rotation=0, ha='right')
plt.tight_layout()

leg = plt.legend(title='Method', frameon=False)
leg.get_title().set_fontweight('bold')
for text in leg.get_texts():
    text.set_fontweight('bold')

plt.savefig(f'{save_path}/lineplot_combined.png', dpi=600)
plt.savefig(f'{save_path}/lineplot_combined.pdf', dpi=600)

plt.show()

# %%
# Predicted and Observed in separate plots

# %%
plt.figure(figsize=(8, 4))
sns.lineplot(
    data=df_pred,
    x='time',
    y='value',
    marker='o',
    linestyle='-',
    linewidth=2.5,
    markersize=8,
    markeredgecolor='k',
    color=color_pred,
)

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(f'{save_path}/lineplot_predicted.png', dpi=600)
plt.savefig(f'{save_path}/lineplot_predicted.pdf', dpi=600)
plt.show()

# %%
sns.lineplot(
    data=df_gt,
    x='time',
    y='value',
    marker='o',
    linestyle='-',
    linewidth=2.5,
    markersize=8,
    markeredgecolor='k',
    color=color_gt,
)

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(f'{save_path}/lineplot_observed.png', dpi=600)
plt.savefig(f'{save_path}/lineplot_observed.pdf', dpi=600)
plt.show()

# %% [markdown]
# # pvalues of previous time stamps

# %%
list(palette.keys())[2:]
# Out:
# ['C7', 'C14', 'C28', 'R1', 'R2', 'R3', 'R7', 'R14', 'R28']

# %%
tps = list(palette.keys())

# %%
from scipy.stats import ttest_ind

# %%
for gene_name in ['Psca']: #['Pbsn', 'Tgm4', 'Krt18', 'Psca']:
    for idx, tp in enumerate(tps):
        cur_time = tps[idx]
        
        if idx != 0:
            prev_time = tps[idx-1]
            pval_gt = ttest_ind(
                adata_cat_gt[adata_cat_gt.obs['time'] == cur_time][:, gene_name].X, 
                             
                adata_cat_gt[adata_cat_gt.obs['time'] == prev_time][:, gene_name].X
            )[1]

            pval_pred = ttest_ind(
                adata_cat_pred[adata_cat_pred.obs['time'] == 'C7'][:, gene_name].X, 
                             
                adata_cat_pred[adata_cat_pred.obs['time'] == 'T0'][:, gene_name].X
            )[1]
            
            print('observed', gene_name, cur_time, prev_time, pval_gt, '\n')
            print('predicted', gene_name, cur_time, prev_time, pval_pred, 'n')

    print('---------------------------\n\n')
# Out:
# observed Psca C1 T0 [0.0363923]
#
# predicted Psca C1 T0 [1.3899557e-07] n
# observed Psca C7 C1 [0.03731681]
#
# predicted Psca C7 C1 [1.3899557e-07] n
# observed Psca C14 C7 [0.00028851]
#
# predicted Psca C14 C7 [1.3899557e-07] n
# observed Psca C28 C14 [0.00095723]
#
# predicted Psca C28 C14 [1.3899557e-07] n
# observed Psca R1 C28 [0.00056399]
#
# predicted Psca R1 C28 [1.3899557e-07] n
# observed Psca R2 R1 [0.02926193]
#
# predicted Psca R2 R1 [1.3899557e-07] n
# observed Psca R3 R2 [0.40688241]
#
# predicted Psca R3 R2 [1.3899557e-07] n
# observed Psca R7 R3 [1.31234516e-15]
#
# predicted Psca R7 R3 [1.3899557e-07] n
# observed Psca R14 R7 [0.12950327]
#
# predicted Psca R14 R7 [1.3899557e-07] n
# observed Psca R28 R14 [0.00042879]
#
# predicted Psca R28 R14 [1.3899557e-07] n
# ---------------------------
