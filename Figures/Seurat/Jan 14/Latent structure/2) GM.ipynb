# %% [markdown]
# # Imports

# %%
import scanpy as sc
from tqdm import tqdm

import sys
sys.path.append('../../')
import GM

# %% [markdown]
# # Read adata containing structured latent

# %%
adata_structured = sc.read_h5ad(
    'adata_structured_balanced.h5ad'
)

adata = sc.AnnData(
    adata_structured.obsm['map_latent_summed'].copy(),
    obs=adata_structured.obs.copy(),
    obsm=adata_structured.obsm.copy()
)
# Out:
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/SE/miniconda3/envs/trials/lib/python3.10/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
del adata_structured

# %%
# adata.obs['celltype.l1'] = adata.obs['celltype.l1'].astype(str)
# adata.obs['celltype.l2'] = adata.obs['celltype.l2'].astype(str)
# adata.obs['celltype.l1'][adata.obs['celltype.l1'] == 'other T'] = adata[adata.obs['celltype.l1'] == 'other T'].obs['celltype.l2'].copy()

# %%
adata.obs['cell_type'] = adata.obs['celltype.l1'].copy()

# %% [markdown]
# # Get tree

# %%
tree_results = GM.get_tree(
    adata, 
    final_level=15,
    step=None,
    cell_type_key='cell_type',

    n_comps=26,
    standardize=False,
    random_state=42,
    n_pcs=30,
    obsm_key=None,
    dynamic_comps=False,
    )
# Out:
# Applying PCA
# Applying PCA
# Applying PCA
# Applying PCA
# Applying PCA
# Applying PCA
# Applying PCA
# Applying PCA

# %% [markdown]
# # Plot Tree

# %%
import os
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram

# %%
save_path ='/data/scDisentangle figures/Seurat/dendro'
os.makedirs(save_path, exist_ok=True)

# %%
GM.plot_dendro(
    tree_results['linkage_mtx'], 
    tree_results['clusters'], 
    figsize=(14, 6),
    linewidth=7,
    orientation='top',
    save_path='/data/scDisentangle figures/Seurat/dendro/'
    )
# Out:
# saving to /data/scDisentangle figures/Seurat/dendro
